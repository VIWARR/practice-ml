# %%
import numpy as np
import pandas as pd

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %% [markdown]
# #### Загружаем датасет. Определяем матрицу признаков X и векторный массив классов видов цветков y

# %%
iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target

# %% [markdown]
# #### Разделяем данные на 30% тестовые и 70% обучающие

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y
)

# %%
print(
    f'Количество меток в y: {np.bincount(y)}\n'
    f'Количество меток в y_train: {np.bincount(y_train)}\n'
    f'Количество меток в y_test: {np.bincount(y_test)}\n'
)
# Out:
# Количество меток в y: [50 50 50]
# Количество меток в y_train: [35 35 35]
# Количество меток в y_test: [15 15 15]

# %% [markdown]
# #### Визуализируем данные для обучения

# %%
plt.scatter(
    X_train[y_train == 0, 0], X_train[y_train == 0, 1], 
    color='red', marker='o', label='Setosa'
)

plt.scatter(
    X_train[y_train == 1, 0], X_train[y_train == 1, 1], 
    color='blue', marker='o', label='Versicolor'
)

plt.xlabel('Длина чашелистика [см]')
plt.ylabel('Длина лепестка [см]')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# #### Стандартизируем признаки
#
# ``` z = (x - μ) / σ ```
#
# **Где:**
# - \( x \) — значение наблюдения, для которого вычисляется Z-оценка,
# - \( μ \) — среднее значение выборки,
# - \( σ \) — стандартное отклонение выборки.
# ти).

# %%
sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# #### Обучаем модель со стандартизированными данными

# %%
ppn_std = Perceptron(eta0=0.1, random_state=1)
ppn_std.fit(X_train_std, y_train)
# Out:
# Perceptron(eta0=0.1, random_state=1)

# %% [markdown]
# #### Обучаем модель без стандартизации данных

# %%
ppn = Perceptron(eta0=0.1, random_state=1)
ppn.fit(X_train, y_train)
# Out:
# Perceptron(eta0=0.1, random_state=1)

# %% [markdown]
# ---

# %% [markdown]
# #### Функция для отображения кол-ва ошибок и эпох для модели

# %%
def vis_count_errors_epoch(ppn):
    errors = []
    for epoch in range(1, ppn.n_iter_ + 1):
        errors.append(ppn.n_iter_ - epoch)
    plt.plot(range(1, len(errors) + 1), errors, marker='s')
    plt.xlabel('Эпохи')
    plt.ylabel('Кол-во ошибок')
    plt.show()

# %% [markdown]
# 1. Выводим кол-во ошибок и эпох для модели со стандартизированными данными

# %%
vis_count_errors_epoch(ppn_std)

# %% [markdown]
# 2. Выводим кол-во ошибок и эпох для модели без стандартизации

# %%
vis_count_errors_epoch(ppn)

# %% [markdown]
# ---

# %% [markdown]
# #### Прогноз на тестовой выборке

# %% [markdown]
# 1. Стандартизованные данные

# %%
y_pred_std = ppn_std.predict(X_test_std)
print('Точность: %.3f' % accuracy_score(y_test, y_pred_std))
# Out:
# Точность: 0.978

# %% [markdown]
# 2. Данные без стандартизации

# %%
y_pred = ppn.predict(X_test)
print('Точность: %.3f' % accuracy_score(y_test, y_pred))
# Out:
# Точность: 0.667

# %% [markdown]
# ---

# %% [markdown]
# #### Функция визуализации области решений

# %%
def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):
    # Настройка генератора меток и цветовой карты
    markers = ('o', 's', '^', 'v', '<')  # Используем правильные символы для маркеров
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])  # Создаем цветовую карту для уникальных классов

    # Строим поверхность решений
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1  # Границы для первого признака
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1  # Границы для второго признака
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution), np.arange(x2_min, x2_max, resolution))  # Сетка точек

    # Прогнозируем классы для всех точек на сетке
    lab = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    lab = lab.reshape(xx1.shape)  # Возвращаем в форму сетки

    # Отображаем области решения
    plt.contourf(xx1, xx2, lab, alpha=0.3, cmap=cmap)
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    # Отображаем точки данных
    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0],
                    y=X[y == cl, 1],
                    alpha=0.8,
                    c=colors[idx],
                    marker=markers[idx],
                    label=f'Class {cl}',
                    edgecolor='black')

    # Если есть индексы тестовых данных, отображаем их
    if test_idx:
        X_test, y_test = X[test_idx, :], y[test_idx]
        plt.scatter(X_test[:, 0], X_test[:, 1],
                    c='none', edgecolor='black', alpha=1.0,
                    linewidth=1, marker='o',
                    s=100, label='Test set')

# %% [markdown]
# 1. Выводим области решений со стандартизацией признаков

# %%
# Объединение тренировочных и тестовых данных
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X=X_combined_std, 
                      y=y_combined, 
                      classifier=ppn_std, 
                      test_idx=range(105, 150))

plt.xlabel('Длина лепестка [стандартизованная]')
plt.ylabel('Ширина лепестка [стандартизованная]')
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Выводим области решений без стандартизации признаков

# %%
# Объединение тренировочных и тестовых данных
X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X=X_combined, 
                      y=y_combined, 
                      classifier=ppn, 
                      test_idx=range(105, 150))

plt.xlabel('Длина лепестка [стандартизованная]')
plt.ylabel('Ширина лепестка [стандартизованная]')
plt.tight_layout()
plt.show()
